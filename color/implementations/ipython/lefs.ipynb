# %% [markdown]
# # Luminous Efficiency Functions

# %% [markdown]
# The [luminous efficiency function](http://en.wikipedia.org/wiki/Luminosity_function) characterizes the average spectral sensitivity of human visual perception of brightness. [Brightness](http://en.wikipedia.org/wiki/Brightness) is defined as the attribute of a visual sensation according to which an area appears to emit more or less light. [Photometry](http://goo.gl/JNMw6u) is the science of measurement of the intensity of light in terms of its perceived brightness to the human visual system.

# %% [markdown]
# ## Photometry & Radiometry

# %% [markdown]
# Photometry is analogous to [radiometry](http://en.wikipedia.org/wiki/Radiometry) but is dedicated to the measurement of electromatic radiation frequencies over the visible spectrum. Photometric quantities are weighted accordingly to human visual system spectral sensitivity within the wavelength range 360-780 nanometres (nm) while radiometric quantities represent unweighted absolute power within the wavelength range 0.01-1000 micrometres (mm).
#
# Given the following terms and units table:
#
# |  Term                                                                        | Symbol           | Defining Equation                                                                                                                                                                              | Units                         | Units Name                                                            | Notes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |------------------------------------------------------------------------------|:----------------:|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------:|:---------------------------------------------------------------------:|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | [Frequency](http://en.wikipedia.org/wiki/Frequency)                          | $v$              |                                                                                                                                                                                                | $s^{-1}$                      |                                                                       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | [Wavelength](http://en.wikipedia.org/wiki/Wavelength)                        | $\lambda$        | $\lambda=\cfrac{c}{v}$                                                                                                                                                                         | $m$                           | Metre                                                                 | $c$: Velocity of radiant energy in vacuum                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | [Wavenumber](http://en.wikipedia.org/wiki/Wavenumber)                        | $m$              | $m=\cfrac{1}{\lambda}$                                                                                                                                                                         | $m^{-1}$                      | Metre                                                                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | [Solid angle](http://en.wikipedia.org/wiki/Solid_angle)                      | $\omega$         | $\omega=\cfrac{S}{r^2}$                                                                                                                                                                        | $sr$                          | Steradian                                                             | $S$: Portion of sphere surface<br>$r$: Radius of sphere, also distance between (1) of $dA_1$ and (2) of $dA_2$$\phantom{\ \ \ \ \ \ \ \ \ \ }$$\phantom{\ \ \ \ \ \ \ \ \ \ }$$\phantom{\ \ \ \ \ \ \ \ \ \ }$$\phantom{\ \ \ \ \ \ \ \ \ \ }$$\phantom{\ \ \ \ \ \ \ \ \ \ }$$\phantom{\ \ \ }$                                                                                                                                                                                                                                                                                                         |
#
# Radiometry uses the following quantities, terms and units:
#
# | Quantity / Term                                                              | Symbol           | Defining Equation                                                                                                                                                                              | Units                         | Units Name                                                            | Notes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |------------------------------------------------------------------------------|:----------------:|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------:|:---------------------------------------------------------------------:|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | [Radiant energy](http://en.wikipedia.org/wiki/Radiant_energy)                | $Q_e$            |                                                                                                                                                                                                | $J$                           | Joule                                                                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | [Radiant flux](http://en.wikipedia.org/wiki/Radiant_flux) (or power)         | $P_e$            |                                                                                                                                                                                                | $W$                           | Watt<br>($J\cdot sr^{-1}$)                                            | $d^2P_e=L_e\cfrac{dA_1\cos\varepsilon_1dA_2\cos\varepsilon_2}{r^2}$                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | [Radiant exitance](http://en.wikipedia.org/wiki/Radiant_exitance)            | $M_e$            | $M_e=\cfrac{dP_e}{dA_1}$                                                                                                                                                                       | $W\cdot m^{-2}$               | Watt per square metre                                                 | $dA_1$: Surface element of source                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | [Irradiance](http://en.wikipedia.org/wiki/Irradiance)                        | $E_e$            | $E_e=\cfrac{dP_e}{dA_2}$                                                                                                                                                                       | $W\cdot m^{-2}$               | Watt per square metre                                                 | $dA_1$: Surface element of receiver                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | [Radiant intensity](http://en.wikipedia.org/wiki/Radiant_intensity)          | $I_e$            | $I_e=\cfrac{dP_e}{d\omega_1}$                                                                                                                                                                  | $W\cdot sr^{-1}$              | Watt per steradian                                                    | $d\omega_1$: Element of solid angle with apex (2) at surface of source                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | [Radiance](http://en.wikipedia.org/wiki/Radiance)                            | $L_e$            | $L_e=\cfrac{d^2P_e}{dA_1\cos\varepsilon_1d\omega_1}$<br>$L_e=\cfrac{d^2E_e}{dA_2\cos\varepsilon_2d\omega_2}$<br>$L_e=\cfrac{d(E_e)_n}{d\omega_2}$                                              | $W\cdot m^{-2} \cdot sr^{-1}$ | Watt per square metre per steradian                                   | $\varepsilon_1$: Angle between direction (1)-(2) and normal $n_1$ of $dA_1$<br>$\varepsilon_2$: Angle between direction (1)-(2) and normal $n_2$ of $dA_2$<br>$d\omega_2$: Element of solid angle with apex (2) at surface of receiver<br>$dA_1\cos\varepsilon_1$: $dA_1$ orthogonally projected on plane perpendicular to direction (1)-(2)<br>$dA_2\cos\varepsilon_2$: $dA_2$ orthogonally projected on plane perpendicular to direction (1)-(2)<br>$d(E_e)_n=\cfrac{dE_e}{dA_2\cos\varepsilon_2}$<br>$d\omega_1=\cfrac{dA_1\cos\varepsilon_1}{r^2}$<br>$d\omega_2=\cfrac{dA_2\cos\varepsilon_2}{r^2}$ |
#
#
# Photometry uses the following quantities, terms and units:
#
# | Quantity / Term                                                              | Symbol           | Defining Equation                                                                                                                                                                              | Units                         | Units Name                                                            | Notes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |------------------------------------------------------------------------------|:----------------:|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------:|:---------------------------------------------------------------------:|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | [Luminous energy](http://en.wikipedia.org/wiki/Luminous_energy)              | $Q_v$            |                                                                                                                                                                                                | $lm\cdot s$                   | Lumen second                                                          |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | [Luminous flux](http://en.wikipedia.org/wiki/Luminous_flux) (or power)       | $F_v$ (or $P_v$) | $F_v=KP_e$<br>$F_v=K_m\int_\lambda P_{e,\lambda}V(\lambda)d\lambda$                                                                                                                            | $lm$                          | Lumen<br>($cd\cdot sr$)                                               | $P_e$: Radiant flux ($W$)<br>$K$: Luminous efficacy ($lm\cdot W^{-1}$)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | [Luminous exitance](http://en.wikipedia.org/wiki/Luminous_emittance)         | $Mv$             | $M=\cfrac{dF_v}{dA_1}$                                                                                                                                                                         | $lx$                          | Lumen per square metre (or lux)<br>($lm\cdot m^{-2}$)                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | [Illuminance](http://en.wikipedia.org/wiki/Illuminance)                      | $E_v$            | $E_v=\cfrac{dF_v}{dA_2}$                                                                                                                                                                       | $lx$                          | Lumen per square metre (or lux)<br>($lm\cdot m^{-2}$)                 | $dA_2$: Surface element of receiver                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | [Luminous intensity](http://en.wikipedia.org/wiki/Luminous_intensity)        | $I_v$            | $I_v=\cfrac{dF_v}{d\omega_I}$                                                                                                                                                                  | $cd$                          | Candela<br>($lm\cdot sr^{-1}$)                                        | Luminous flux per unit solid angle<br>$d\omega_I$: Element of solid angle with apex (1) at surface of source                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | [Luminance](http://en.wikipedia.org/wiki/Luminance)                          | $L_v$            | $L_v=\cfrac{d^2F_v}{dA_1\cos\varepsilon_1d\omega_1}$<br>$L_v=\cfrac{dI_v}{dA_1\cos\varepsilon_1}$<br>$L_v=\cfrac{d^2E_v}{dA_2\cos\varepsilon_2d\omega_2}$<br>$L_v=\cfrac{dE_{v,n}}{d\omega_2}$ | $cd\cdot m^{-2}$              | Candela per square metre (or nits)<br>($lm\cdot m^{-2}\cdot sr^{-1}$) | $dA_1$: Surface element of source<br>$\varepsilon_1$ Angle between direction (1)-(2) and normal $n_1$ of $dA_1$<br>$dA_1\cos\varepsilon_1$: $dA_1$ orthogonally projected on plane perpendicular to direction (1)-(2)<br>$dE_{v, n}$: Illuminance on $dA_2$ normal to the direction (1)-(2)<br>$d\omega_2$: Element of solid angle with apex (2) at surface of receiver                                                                                                                                                                                                                                  |
# | [Luminous efficacy function](http://en.wikipedia.org/wiki/Luminous_efficacy) | $K(\lambda)$     | $K(\lambda)=K_mV(\lambda)$<br>with $K_m$=683                                                                                                                                                   |                               |                                                                       | $V(\lambda)$: Relative photopic luminous efficiency function                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
#
# The following figures illustrate the notes from the above tables:

# %%
from IPython.core.display import Image 
Image(filename="resources/images/Photometric_Quantities_001.png")

# %%
from IPython.core.display import Image 
Image(filename="resources/images/Solid_Angle_001.png")

# %% [markdown]
# As per the above tables, a quantity in the photometric system has a similar quantity in the radiometric system:
#
# * *Radiant energy* and *luminous energy*.
# * *Radiant flux* and *luminous flux*.
# * *Radiance exitance* and *luminous exitance*.
# * *Irradiance* and *Illuminance*.
# * *Radiant intensity* and *luminous intensity*.
# * *Radiance* and *luminance*.
#
# > Reference: **Wyszecki & Stiles**, *Color Science - Concepts and Methods Data and Formulae - Second Edition*, Pages 2, 3, 250.

# %% [markdown]
# ## Photoreceptors

# %% [markdown]
# The human eye has two different types of [photoreceptor cells](http://en.wikipedia.org/wiki/Photoreceptor_cell):
#
# * The [cone cells](http://en.wikipedia.org/wiki/Cone_cell) are mediating the [photopic vision](http://en.wikipedia.org/wiki/Photopic_vision), responsible for color perception. In the photoreceptor layer of the [retina](http://en.wikipedia.org/wiki/Retina), around $6.8\cdot 10^6$ cone cells of types $S$, $M$, $L$ are measuring light with respective peak absorption at wavelengths of about 420 nm, 534 nm and 564 nm. Photopic vision luminance levels are defined for $L_v>10\ cd\cdot m^{-2}$.
# * The [rod cells](http://en.wikipedia.org/wiki/Rod_cell) are mediating the [scotopic vision](http://en.wikipedia.org/wiki/Scotopic), the vision under dim light conditions. There are an average of $110-125\cdot 10^6$ rod cells in the retina although none are located in the central [fovea](http://en.wikipedia.org/wiki/Fovea) region. Scotopic vision luminance levels are defined for $L_v<0.01\ cd\cdot m^{-2}$.

# %% [markdown]
# ## Luminous Efficiency Functions

# %% [markdown]
# [Color](https://github.com/KelSolaar/Color/) provides the following photopic and scotopic luminous efficiency functions:

# %%
import color

print(sorted(color.PHOTOPIC_LEFS.keys()))
print(sorted(color.SCOTOPIC_LEFS.keys()))
# Out:
# [u'CIE 1924 Photopic Standard Observer', u'Judd Modified CIE 1951 Photopic Standard Observer', u'Judd-Vos Modified CIE 1978 Photopic Standard Observer', u'Stockman, Jagle, Pirzer & Sharpe CIE 2008 10 Degree Observer', u'Stockman, Jagle, Pirzer & Sharpe CIE 2008 2 Degree Standard Observer']
# [u'CIE 1951 Scotopic Standard Observer']

# %% [markdown]
# ### CIE 1924 Photopic Standard Observer

# %% [markdown]
# The *CIE 1924 Photopic Standard Observer* luminous efficiency function $V(\lambda)$ was established by the *CIE* in 1924 and is a relative function of wavelength with peak at $\lambda_d=555\ nm$.
#
# Photopic luminous flux $P_v$ and radiant flux $P_e$ are related by the following equation:
#
# $$
# P_v=K_m\int_\lambda P_{e,\lambda}V(\lambda)d\lambda
# $$
#
# Accordingly, the photopic luminous efficacy $K$ defined as follows:
#
# $$
# K(\lambda)=\cfrac{P_{v,\lambda}}{P_{e,\lambda}}
# $$
#
# is equal to:
#
# $$
# K(\lambda)=K_mV(\lambda)
# $$
#
# with $K_m=683\ lm\cdot W^-1$ at $\lambda_d=555\ nm$.
#
# > Reference: **Wyszecki & Stiles**, *Color Science - Concepts and Methods Data and Formulae - Second Edition*, Page 256.
#
# The *CIE 1924 Photopic Standard Observer* luminous efficiency function $V(\lambda)$ has the following range and increments:

# %%
color.PHOTOPIC_LEFS["CIE 1924 Photopic Standard Observer"].shape

# %%
from color.implementations.matplotlib.plots import *

multi_spectral_power_distribution_plot(
    [color.PHOTOPIC_LEFS["CIE 1924 Photopic Standard Observer"]],
    y_label="Luminous Efficiency",
    legend_location="upper right",
    y_tighten=True,
    margins=[0., 150., 0., .1])
# Out:
# True

# %% [markdown]
# ### CIE 1951 Scotopic Standard Observer

# %% [markdown]
# The *CIE 1951 Scotopic Standard Observer* luminous efficiency function $V^\prime(\lambda)$ was established by the *CIE* in 1951 and is a relative function of wavelength with peak at $\lambda_d=507\ nm$.
#
# Scotopic luminous flux $P_v^\prime$ and radiant flux $P_e$ are related by the following equation:
#
# $$
# P_v^\prime=K_m\int_\lambda P_{e,\lambda}^\prime V(\lambda)d\lambda
# $$
#
# Accordingly, the scotopic luminous efficacy $K^\prime$ defined as follows:
#
# $$
# K^\prime(\lambda)=\cfrac{P_{v,\lambda}^\prime}{P_{e,\lambda}}
# $$
#
# is equal to:
#
# $$
# K^\prime(\lambda)=K_m^\prime V(\lambda)
# $$
#
# with $K_m=1700\ lm\cdot W^-1$ at $\lambda_d=507\ nm$.
#
# > Reference: **Wyszecki & Stiles**, *Color Science - Concepts and Methods Data and Formulae - Second Edition*, Page 256.
#
# The *CIE 1951 Scotopic Standard Observer* luminous efficiency function $V^\prime(\lambda)$ has the following range and increments:

# %%
color.SCOTOPIC_LEFS["CIE 1951 Scotopic Standard Observer"].shape
# Out:
# (380, 780, 1)

# %%
multi_spectral_power_distribution_plot(
    [color.SCOTOPIC_LEFS["CIE 1951 Scotopic Standard Observer"]],
    y_label="Luminous Efficiency",
    legend_location="upper right",
    y_tighten=True,
    margins=[0., 150., 0., .1])
# Out:
# True

# %% [markdown]
# ### Mesopic Vision

# %% [markdown]
# [Mesopic vision](http://en.wikipedia.org/wiki/Mesopic) is a combination of photopic vision and scotopic vision and is defined for for $L_v\pm 0.2\ cd\cdot m^{-2}$. Although there is no standard for mesopic vision, a weighting function $V_m(\lambda)$ is defined as follows:
#
# $$
# V_m(\lambda)=(1-x)V^\prime(\lambda)+xV(\lambda)
# $$
#
# where $x$ is function of photopic luminance $L_p$ and can have value of:
#
# | $L_p$ | Blue-heavy<br>(MOVE) | Blue-heavy<br>(LRC) | Red-heavy<br>(MOVE) | Red-heavy<br>(LRC) |
# |:-----:|:--------------------:|:-------------------:|:-------------------:|:------------------:|
# | 0.01  | 0.13                 | 0.04                | 0.00                | 0.01               |
# | 0.1   | 0.42                 | 0.28                | 0.34                | 0.11               |
# | 1.0   | 0.70                 | 1.00                | 0.68                | 1.00               |
# | 10    | 0.98                 | 1.00                | 0.98                | 1.00               |
#
# The [MOVE](http://www.move.vu.nl/en/) is an european research consortium and [LRC](http://www.lrc.rpi.edu/) stands for Lighting Research Center.
#
# > Reference: http://en.wikipedia.org/wiki/Mesopic#Mesopic_weighting_function
#
# The *color.mesopic_weighting_function* implements support for mesopic vision following the above equation:

# %%
color.mesopic_weighting_function(wavelength=500, Lp=0.2)
# Out:
# 0.7052200000000001

# %% [markdown]
# We can use different parameters for $x$:

# %%
color.mesopic_weighting_function(500, 0.2, source="Red Heavy", method="LRC")
# Out:
# 0.9095099999999999

# %%
mesopic_luminous_efficiency_function_data = dict((i, color.mesopic_weighting_function(i, 0.2)) for i in range(380, 780, 5))
mesopic_luminous_efficiency_function_spd = color.SpectralPowerDistribution("Mesoic Luminous Efficiency Function",
                                                                           mesopic_luminous_efficiency_function_data)

# Normalising the spectral power distribution to 1.0.
mesopic_luminous_efficiency_function_spd.normalize()

multi_spectral_power_distribution_plot(
    [mesopic_luminous_efficiency_function_spd,
color.PHOTOPIC_LEFS["CIE 1924 Photopic Standard Observer"], color.SCOTOPIC_LEFS["CIE 1951 Scotopic Standard Observer"]],
    y_label="Luminous Efficiency",
    legend_location="upper right",
    y_tighten=True,
    margins=[0., 150., 0., .1])
# Out:
# True
