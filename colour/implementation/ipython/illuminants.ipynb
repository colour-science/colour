# %% [markdown]
# # Illuminants

# %% [markdown]
# An illuminant is a radiation with a relative spectral power distribution defined over the wavelength range that influences object colour perception. <a name="back_reference_1"><a href="#reference_1">[1]</a></a>
#
# [Colour](https://github.com/KelSolaar/Colour/) provides the following illuminant spectral power distributions:

# %%
import colour

print(sorted(colour.ILLUMINANTS_RELATIVE_SPDS.keys()))
# Out:
# [u'A', u'B', u'C', u'D50', u'D55', u'D60', u'D65', u'D75', u'E', u'F1', u'F10', u'F11', u'F12', u'F2', u'F3', u'F4', u'F5', u'F6', u'F7', u'F8', u'F9', u'FL3.1', u'FL3.10', u'FL3.11', u'FL3.12', u'FL3.13', u'FL3.14', u'FL3.15', u'FL3.2', u'FL3.3', u'FL3.4', u'FL3.5', u'FL3.6', u'FL3.7', u'FL3.8', u'FL3.9', u'HP1', u'HP2', u'HP3', u'HP4', u'HP5']

# %% [markdown]
# ## CIE Standard Illuminant A

# %% [markdown]
# As per *CIE publication CIE S005/E-1998*: <a name="back_reference_2"><a href="#reference_2">[2]</a></a>
#
# > [CIE Standard Illuminant A](http://en.wikipedia.org/wiki/Standard_illuminant#Illuminant_A) is intended to represent typical, domestic, tungsten-filament lighting. Its relative spectral power distribution is that of a Planckian radiator at a temperature of approximately 2856 K. *CIE Standard Illuminant A* should be used in all applications of colorimetry involving the use of incandescent lighting, unless there are specific reasons for using a different illuminant.
#
# The *CIE Standard Illuminant A* has the following range and increments:

# %%
colour.ILLUMINANTS_RELATIVE_SPDS["A"].shape
# Out:
# (300, 780, 5)

# %%
from colour.implementation.matplotlib.plots import *

single_illuminant_relative_spd_plot("A")
# Out:
# True

# %% [markdown]
# ## CIE Illuminant B

# %% [markdown]
# The [CIE Illuminant B](http://en.wikipedia.org/wiki/Standard_illuminant#Illuminants_B_and_C) is a daylight simulator intended to represent direct noon sunlight with a *correlated colour temperature* of 4874 K.
#
# The *CIE Illuminant B* has the following range and increments:

# %%
colour.ILLUMINANTS_RELATIVE_SPDS["B"].shape
# Out:
# (320, 780, 5)

# %%
single_illuminant_relative_spd_plot("B")
# Out:
# True

# %% [markdown]
# ## CIE Illuminant C

# %% [markdown]
# The [CIE Illuminant C](http://en.wikipedia.org/wiki/Standard_illuminant#Illuminants_B_and_C) is also a daylight simulator but intended to represent average daylight with a *correlated colour temperature* of 6774 K.
#
# The *CIE Illuminant B* and *CIE Illuminant C* are poor approximations of any common light source and deprecated in favor of *CIE Illuminant D Series*. Both are deficient in their spectral distribution in the ultraviolet region which is important for fluorescent materials.
#
# As per *CIE publication CIE 15:2004 "Colorimetry"*: <a name="back_reference_3"><a href="#reference_3">[3]</a></a>
#
# > Illuminant C does not have the status of a CIE standard but its relative spectral power distribution, tristimulus values and chromaticity coordinates are given in Table T.1 and Table T.3, as many practical measurement instruments and calculations still use this illuminant.
#
# The *CIE Illuminant C* has the following range and increments:

# %%
colour.ILLUMINANTS_RELATIVE_SPDS["C"].shape
# Out:
# (300, 780, 5)

# %%
single_illuminant_relative_spd_plot("C")
# Out:
# True

# %% [markdown]
# *CIE Standard Illuminant A*, *CIE Illuminant B*, and *CIE Illuminant C* relative spectral power distributions are shown here altogether:

# %%
multi_illuminants_relative_spd_plot(["A", "B", "C"])
# Out:
# True

# %%
# Plotting *CIE Standard Illuminant A*, *CIE Illuminant B*, and * CIE Illuminant C* with their normalized colours.
multi_illuminants_relative_spd_plot(["A", "B", "C"],
                                    use_spds_colours=True,
                                    normalize_spds_colours=True)
# Out:
# True

# %% [markdown]
# *CIE Standard Illuminant A*, *CIE Illuminant B*, and * CIE Illuminant C* chromaticity coordinates plotted against the [Planckian Locus](http://en.wikipedia.org/wiki/Planckian_locus) into the *CIE 1931 Chromaticity Diagram*:

# %%
planckian_locus_CIE_1931_chromaticity_diagram_plot(["A", "B", "C"])
# Out:
# True

# %% [markdown]
# Notice how the isotemperature lines are not perpendicular to the *Planckian Locus*, the *CIE 1960 UCS Chromaticity Diagram* with perpendicular isotemperature lines is better suited for *correlated colour temperature* calculations:

# %%
planckian_locus_CIE_1960_UCS_chromaticity_diagram_plot(["A", "B", "C"])
# Out:
# True

# %%
# Zooming into the *Planckian Locus*.
planckian_locus_CIE_1960_UCS_chromaticity_diagram_plot(["A", "B", "C"], bounding_box=[0.15, 0.35, 0.25, 0.45])
# Out:
# True

# %% [markdown]
# ##  CIE Illuminant D Series

# %% [markdown]
# The [CIE Illuminant D Series](http://en.wikipedia.org/wiki/Standard_illuminant#Illuminant_series_D) are intended to model natural daylight and should be used in all colourimetric calculations requiring representative daylight. <a name="back_reference_2"><a href="#reference_2">[2]</a></a>
#
# The *CIE Standard Illuminant D65* defines the relative spectral power distribution representing a phase of daylight with a correlated colour temperature of approximately 6 500 K (called also "nominal correlated colour temperature of the daylight illuminant"). <a name="back_reference_4"><a href="#reference_4">[4]</a></a>
#
# > Note: *CIE Standard Illuminant A* and *CIE Standard Illuminant D65* are the only illuminants considered as *standard* in the *CIE Colour System*. <a name="back_reference_4"><a href="#reference_4">[4]</a></a>
#
# Relative spectral power distributions of the following *CIE Illuminant D Series* are available:

# %%
import re
sorted(filter(lambda x: re.match("D\d{2}", x), colour.ILLUMINANTS_RELATIVE_SPDS.keys()))
# Out:
# [u'D50', u'D55', u'D60', u'D65', u'D75']

# %% [markdown]
# The relative spectral power distribution $\lbrace S_D(\lambda)d\lambda\rbrace$ of a *CIE Illuminant D Series* is the result of the linear combination of a mean distribution $\lbrace S_0(\lambda)d\lambda\rbrace$ and two distributions $\lbrace S_1(\lambda)d\lambda\rbrace$ and $\lbrace S_2(\lambda)d\lambda\rbrace$ being the most important *eigen vectors* of the all daylight distributions: <a name="back_reference_5"><a href="#reference_5">[5]</a></a>
#
# $$
# \begin{equation}
# S_D(\lambda)=S_0(\lambda)+M_1S_1(\lambda)+M_2S_2(\lambda)
# \end{equation}
# $$
# where
# $$
# \begin{equation}
# M_1=\cfrac{-1.3515-1.7703x_d+5.9114y_d}{M}\\
# M_2=\cfrac{0.0300-31.4424x_d+30.0717y_d}{M}\\
# M=0.0241+0.2562x_d-0.7341y_d
# \end{equation}
# $$
#
# The *CIE Illuminant D Series* have the following range and increments:

# %%
for key, value in sorted(colour.ILLUMINANTS_RELATIVE_SPDS.iteritems()):
    if re.match("D\d{2}", key):
        print("{0}: {1}".format(key, value.shape))
# Out:
# D50: (300, 780, 5)
# D55: (300, 780, 5)
# D60: (300, 830, 10)
# D65: (300, 780, 5)
# D75: (300, 780, 5)

# %%
# Plotting *CIE Illuminant D Series* S spectral power distributions.
multi_spd_plot(sorted(colour.D_ILLUMINANTS_S_SPDS.values()), title="CIE Illuminant D Series - S Distributions")
# Out:
# True

# %%
# Plotting *CIE Illuminant D Series* into the *Planckian Locus*.
planckian_locus_CIE_1960_UCS_chromaticity_diagram_plot(sorted(filter(lambda x: re.match("D\d{2}", x), colour.ILLUMINANTS_RELATIVE_SPDS.keys())),
                                                       bounding_box=[0.15, 0.35, 0.25, 0.45])
# Out:
# True

# %% [markdown]
# ## CIE Illuminant E

# %% [markdown]
# The [CIE Illuminant E](http://en.wikipedia.org/wiki/Standard_illuminant#Illuminant_E) is a theoretical reference equal energy radiator. All the wavelengths of its relative spectral power distribution are weighted equally with a relative spectral power of 100.0. *CIE Illuminant E* is not a *blackbody* so it doesn't have a colour temperature, but it can be approximated by a *CIE Illuminant D Series* with a correlated colour temperature of 5455 K (*CIE Illuminant D55* is the closest match).
#
# The *CIE Illuminant E* has the following range and increments:

# %%
colour.ILLUMINANTS_RELATIVE_SPDS["E"].shape
# Out:
# (300, 780, 5)

# %%
planckian_locus_CIE_1960_UCS_chromaticity_diagram_plot(["D55", "E"], bounding_box=[0.15, 0.35, 0.25, 0.45])
# Out:
# True

# %%
single_illuminant_relative_spd_plot("E")
# Out:
# True

# %% [markdown]
# ## Illuminants F Series

# %% [markdown]
# The [Illuminants F Series](http://en.wikipedia.org/wiki/Standard_illuminant#Illuminant_series_F) are not *CIE Standard Illuminants*, but they have been compiled by the *CIE* for use as representative fluorescent lighting distributions for practical purposes.
#
# The ﬁrst 12, *FL1* to *FL12*, are in three different groups, *Normal*, *Broad-Band*, and *Three-Band*:
#
# * *F1* to *F6* are *Normal* and consist of two *semi-broadband* emissions of antimony and manganese activations in calcium halophosphate phosphor.
# * *F7* to *F9* are *Broad-Band* full-spectrum light fluorescent lamps with multiple phosphors, and higher [colour rendering indexes](http://en.wikipedia.org/wiki/Color_rendering_index).
# * *F10* to *F12* are *Three-Band* illuminants consisting of three *Narrow-Band* emissions caused by ternary compositions of rare-earth phosphors.
#
# *F2*, *F7* and *F11* are intended for use in preference to the others when the choice within each group is not critical.
#
# The subsequent 15, *FL3.1* to *FL3.15*, are in ﬁve different groups: *Halophosphate*, *DeLuxe*, *Three-Band*, *Multi-Band*, and *D65 Simulator*:
#
# * *FL3.1* to *FL3.3* form the *Halophosphate* group.
# * *FL3.4* to *FL3.6* form the *DeLuxe* group.
# * *FL3.7* to *FL3.11* form the *Three-Band* group.
# * *FL3.12* to *FL3.14* form the *Multi-Band* group.
# * *FL3.15* is the *D65 Simulator*.
#
# The *Illuminants F Series* have the following range and increments:

# %%
for key, value in sorted(colour.ILLUMINANTS_RELATIVE_SPDS.iteritems()):
    if re.match("F\d{1,2}|FL3\.\d{1,2}", key):
        print("{0}: {1}".format(key, value.shape))
# Out:
# F1: (380, 780, 5)
# F10: (380, 780, 5)
# F11: (380, 780, 5)
# F12: (380, 780, 5)
# F2: (380, 780, 5)
# F3: (380, 780, 5)
# F4: (380, 780, 5)
# F5: (380, 780, 5)
# F6: (380, 780, 5)
# F7: (380, 780, 5)
# F8: (380, 780, 5)
# F9: (380, 780, 5)
# FL3.1: (380, 780, 5)
# FL3.10: (380, 780, 5)
# FL3.11: (380, 780, 5)
# FL3.12: (380, 780, 5)
# FL3.13: (380, 780, 5)
# FL3.14: (380, 780, 5)
# FL3.15: (380, 780, 5)
# FL3.2: (380, 780, 5)
# FL3.3: (380, 780, 5)
# FL3.4: (380, 780, 5)
# FL3.5: (380, 780, 5)
# FL3.6: (380, 780, 5)
# FL3.7: (380, 780, 5)
# FL3.8: (380, 780, 5)
# FL3.9: (380, 780, 5)

# %%
# Plotting the *Normal* group of fluorescent illuminants.
multi_illuminants_relative_spd_plot(["F1", "F2", "F3", "F4", "F5", "F6"])
# Out:
# True

# %%
# Plotting the *Broad-Band* group of fluorescent illuminants.
multi_illuminants_relative_spd_plot(["F7", "F8", "F9"])
# Out:
# True

# %%
# Plotting the *Three-Band* group of fluorescent illuminants.
multi_illuminants_relative_spd_plot(["F10", "F11", "F12"])
# Out:
# True

# %%
# Plotting the *Halophosphate* group of fluorescent illuminants.
multi_illuminants_relative_spd_plot(["FL3.1", "FL3.2", "FL3.3"])
# Out:
# True

# %%
# Plotting the *DeLuxe* group of fluorescent illuminants.
multi_illuminants_relative_spd_plot(["FL3.4", "FL3.5", "FL3.6"])
# Out:
# True

# %%
# Plotting the *Three-Band* group of fluorescent illuminants.
multi_illuminants_relative_spd_plot(["FL3.7", "FL3.8", "FL3.9", "FL3.10", "FL3.11"])
# Out:
# True

# %%
# Plotting the *Multi-Band* group of fluorescent illuminants.
multi_illuminants_relative_spd_plot(["FL3.12", "FL3.13", "FL3.14"])
# Out:
# True

# %%
# Plotting *D65 Simulator* fluorescent illuminant against *CIE Standard Illuminant D65*.
multi_illuminants_relative_spd_plot(["FL3.15", "D65"])
# Out:
# True

# %% [markdown]
# ## High Pressure Discharge Lamps

# %% [markdown]
# The [High pressure discharge lamps](http://en.wikipedia.org/wiki/Gas-discharge_lamp) are artificial light sources generating light by sending an electrical discharge through an ionized gas.
#
# * *HP1* is a standard high pressure sodium lamp.
# * *HP2* is a colour enhanced high pressure sodium lamp.
# * *HP3* to *HP5* are three types of high pressure metal halide lamps.
#
# The *High pressure discharge lamps* have the following range and increments:

# %%
for key, value in sorted(colour.ILLUMINANTS_RELATIVE_SPDS.iteritems()):
    if re.match("HP\d", key):
        print("{0}: {1}".format(key, value.shape))
# Out:
# HP1: (380, 780, 5)
# HP2: (380, 780, 5)
# HP3: (380, 780, 5)
# HP4: (380, 780, 5)
# HP5: (380, 780, 5)

# %%
# Plotting all *high pressure discharge* lamps.
multi_illuminants_relative_spd_plot(sorted(filter(lambda x: re.match("HP\d", x), colour.ILLUMINANTS_RELATIVE_SPDS.keys())))
# Out:
# True

# %% [markdown]
# ## Chromaticity Coordinates

# %% [markdown]
# For convenience purpose the chromaticity coordinates of the provided illuminants are given for the *CIE 1931 2° Standard Observer* and *CIE 1964 10° Standard Observer*:

# %%
sorted(colour.ILLUMINANTS["CIE 1931 2 Degree Standard Observer"].items())
# Out:
# [(u'A', (0.44757, 0.40745)),
#  (u'B', (0.34842, 0.35161)),
#  (u'C', (0.31006, 0.31616)),
#  (u'D50', (0.34567, 0.3585)),
#  (u'D55', (0.33242, 0.34743)),
#  (u'D60', (0.32168, 0.33767)),
#  (u'D65', (0.31271, 0.32902)),
#  (u'D75', (0.29902, 0.31485)),
#  (u'E', (0.3333333333333333, 0.3333333333333333)),
#  (u'F1', (0.3131, 0.33727)),
#  (u'F10', (0.34609, 0.35986)),
#  (u'F12', (0.43695, 0.40441)),
#  (u'F2', (0.37208, 0.37529)),
#  (u'F3', (0.4091, 0.3943)),
#  (u'F4', (0.44018, 0.40329)),
#  (u'F5', (0.31379, 0.34531)),
#  (u'F6', (0.3779, 0.38835)),
#  (u'F7', (0.31292, 0.32933)),
#  (u'F8', (0.34588, 0.35875)),
#  (u'F9', (0.37417, 0.37281)),
#  (u'FL3.1 ', (0.44067505367083887, 0.4032982400521268)),
#  (u'FL3.10 ', (0.345504278345313, 0.3559512432054011)),
#  (u'FL3.11 ', (0.3245099692216317, 0.343369788104288)),
#  (u'FL3.12 ', (0.4376746480519804, 0.40366659242713887)),
#  (u'FL3.13 ', (0.38305207018919446, 0.37244321884144194)),
#  (u'FL3.14 ', (0.3447222271025105, 0.3609370209728111)),
#  (u'FL3.15 ', (0.3126706172769415, 0.3287545660713704)),
#  (u'FL3.2 ', (0.3807750955454208, 0.37335593850329946)),
#  (u'FL3.3 ', (0.315282999959924, 0.3438607529477053)),
#  (u'FL3.4 ', (0.4429092105157883, 0.40432363641263036)),
#  (u'FL3.5 ', (0.37489860509162237, 0.36715721144008995)),
#  (u'FL3.6 ', (0.34880430112004895, 0.36000066745930004)),
#  (u'FL3.7 ', (0.4384254677714265, 0.4045310539294221)),
#  (u'FL3.8 ', (0.38197740008964315, 0.3831793433643612)),
#  (u'FL3.9 ', (0.3498569555988198, 0.3590880129881551)),
#  (u'HP1 ', (0.5330008227923825, 0.4149532376869364)),
#  (u'HP2 ', (0.4777920749861397, 0.4158404588084794)),
#  (u'HP3 ', (0.4302314003272559, 0.4075170114048384)),
#  (u'HP4 ', (0.38117189471910373, 0.3797265745279147)),
#  (u'HP5 ', (0.37758320909195225, 0.3713479728022603))]

# %%
sorted(colour.ILLUMINANTS["CIE 1964 10 Degree Standard Observer"].items())
# Out:
# [(u'A', (0.45117, 0.40594)),
#  (u'B', (0.3498, 0.3527)),
#  (u'C', (0.31039, 0.31905)),
#  (u'D50', (0.34773, 0.35952)),
#  (u'D55', (0.33411, 0.34877)),
#  (u'D65', (0.31382, 0.331)),
#  (u'D75', (0.29968, 0.3174)),
#  (u'E', (0.3333333333333333, 0.3333333333333333)),
#  (u'F1', (0.31811, 0.33559)),
#  (u'F10', (0.3509, 0.35444)),
#  (u'F11', (0.38541, 0.37123)),
#  (u'F12', (0.44256, 0.39717)),
#  (u'F2', (0.37925, 0.36733)),
#  (u'F3', (0.41761, 0.38324)),
#  (u'F4', (0.4492, 0.39074)),
#  (u'F5', (0.31975, 0.34246)),
#  (u'F6', (0.3866, 0.37847)),
#  (u'F7', (0.31569, 0.3296)),
#  (u'F8', (0.34902, 0.35939)),
#  (u'F9', (0.37829, 0.37045)),
#  (u'FL3.1 ', (0.44983072060097606, 0.3902314548749185)),
#  (u'FL3.10 ', (0.3493448005253757, 0.35498443751900227)),
#  (u'FL3.11 ', (0.32926800293079544, 0.33886544553697306)),
#  (u'FL3.12 ', (0.4422521047116721, 0.40122058660685506)),
#  (u'FL3.13 ', (0.3862752927999335, 0.3742832325728946)),
#  (u'FL3.14 ', (0.34725510277403043, 0.3668082930976077)),
#  (u'FL3.15 ', (0.31461426562662165, 0.3333777810577307)),
#  (u'FL3.2 ', (0.3869241790592931, 0.3657561399067915)),
#  (u'FL3.3 ', (0.3211770463590012, 0.3405012294853132)),
#  (u'FL3.4 ', (0.44812132825245227, 0.39707718739452286)),
#  (u'FL3.5 ', (0.3778142145280147, 0.36662585171298506)),
#  (u'FL3.6 ', (0.35197652659197876, 0.3610945283215212)),
#  (u'FL3.7 ', (0.44430926608426524, 0.3967914695376695)),
#  (u'FL3.8 ', (0.3875889785058527, 0.37630564994236454)),
#  (u'FL3.9 ', (0.3546890235509348, 0.3534450969379135)),
#  (u'HP1 ', (0.543334641014127, 0.40528934193733374)),
#  (u'HP2 ', (0.48264737821938364, 0.4108157059894971)),
#  (u'HP3 ', (0.4355600804884421, 0.39880115305546204)),
#  (u'HP4 ', (0.3851937462655714, 0.3682756593039444)),
#  (u'HP5 ', (0.38031641910835223, 0.3666171209128104))]

# %% [markdown]
# They are either coming from published sources or have been calculated using the *colour.spectral_to_XYZ* and *colour.XYZ_to_xy* definitions:

# %%
cmfs=colour.STANDARD_OBSERVERS_CMFS.get("CIE 1931 2 Degree Standard Observer")
for illuminant, spd in sorted(colour.ILLUMINANTS_RELATIVE_SPDS.iteritems()):
    print illuminant, colour.XYZ_to_xy(colour.spectral_to_XYZ(spd, cmfs))
# Out:
#  A (0.44757143344511391, 0.40744043259459417)
# B
# (0.34840768232868036, 0.3516172372008165)
# C (0.31005847373025541, 0.31614970752323651)
# D50 (0.34566803702927307, 0.35849683893761902)
# D55 (0.33242410246883025, 0.34742803908766623)
# D60
# (0.32167639349760585, 0.33765394119507208)
# D65 (0.31271106772165319, 0.32900848407868266)
# D75 (0.29902230041249711, 0.31485273788834189)
# E (0.33331280004192843, 0.33328674660529761)
# F1 (0.31306243303565101, 0.3371064779183075)
# F10
# (0.34578790072842097, 0.35875792831408843)
# F11 (0.38053748548303012, 0.37691530929393008)
# F12 (0.43702434482815777, 0.40421500068733629)
# F2 (0.37206815445282559, 0.37512255820311008)
# F3 (0.40909003530810728, 0.39411713425536588)
# F4
# (0.44018109582766657, 0.40309069115813834)
# F5 (0.31375734929432714, 0.3451606498472749)
# F6 (0.37787777238111353, 0.38819414946096359)
# F7 (0.31285247291547535, 0.32917417803356763)
# F8 (0.34580575355031595, 0.35861758321437753)
# F9
# (0.37409927195090759, 0.37268419639905115)
# FL3.1 (0.44067505367083887, 0.40329824005212678)
# FL3.10 (0.345504278345313, 0.35595124320540111)
# FL3.11 (0.32450996922163172, 0.34336978810428798)
# FL3.12 (0.43767464805198042, 0.40366659242713887)
# FL3.13
# (0.38305207018919446, 0.37244321884144194)
# FL3.14 (0.34472222710251049, 0.36093702097281111)
# FL3.15 (0.31267061727694151, 0.32875456607137038)
# FL3.2 (0.38077509554542083, 0.37335593850329946)
# FL3.3 (0.31528299995992398, 0.34386075294770529)
# FL3.4 (0.4429092105157883, 0.40432363641263036)
# FL3.5
# (0.37489860509162237, 0.36715721144008995)
# FL3.6 (0.34880430112004895, 0.36000066745930004)
# FL3.7 (0.43842546777142649, 0.40453105392942212)
# FL3.8 (0.38197740008964315, 0.38317934336436121)
# FL3.9 (0.3498569555988198, 0.35908801298815513)
# HP1 (0.53300082279238248, 0.41495323768693643)
# HP2
# (0.47779207498613968, 0.41584045880847942)
# HP3 (0.43023140032725588, 0.40751701140483843)
# HP4 (0.38117189471910373, 0.3797265745279147)
# HP5 (0.37758320909195225, 0.37134797280226028)

# %% [markdown]
# ## References

# %% [markdown]
# 1. <a href="#back_reference_1">^<a> <a name="reference_1"></a>[17-554 illuminant](http://eilv.cie.co.at/term/554) (Last accessed 26 June 2014)
# 2. <a href="#back_reference_2">^<a> <a name="reference_2"></a>[ISO 11664-2:2007(E)/CIE S 014-2/E:2006](http://www.cie.co.at/index.php/index.php?i_ca_id=484) (Last accessed 23 June 2014)
# 3. <a href="#back_reference_3">^<a> <a name="reference_3"></a>https://law.resource.org/pub/us/cfr/ibr/003/cie.15.2004.pdf
# 4. <a href="#back_reference_4">^<a> <a name="reference_4"></a>[17-168 CIE standard illuminants](http://eilv.cie.co.at/term/168) (Last accessed 27 June 2014)
# 5. <a href="#back_reference_5">^<a> <a name="reference_5"></a>[**Bruce Lindbloom**](http://www.brucelindbloom.com/Eqn_DIlluminant.html), **Wyszecki & Stiles**, *Color Science - Concepts and Methods Data and Formulae - Second Edition*, Wiley Classics Library Edition, published 2000, ISBN-10: 0-471-39918-3, Page 146.

# %% [markdown]
# ## Dataset

# %% [markdown]
# 1. *CIE Standard Illuminant A*: http://files.cie.co.at/204.xls (Last accessed 24 February 2014)
# 2. *CIE Illuminant B*: http://onlinelibrary.wiley.com/store/10.1002/9781119975595.app5/asset/app5.pdf?v=1&t=hwc899dh&s=01d1e0b27764970185be52b69b4480f3305ddb6c (Last accessed 12 June 2014)
# 3. *CIE Illuminant C*: https://law.resource.org/pub/us/cfr/ibr/003/cie.15.2004.tables.xls (Last accessed 24 February 2014)
# 4. *CIE Illuminant D Series*: https://law.resource.org/pub/us/cfr/ibr/003/cie.15.2004.tables.xls (Last accessed 24 February 2014)
# 5. *CIE Illuminant E*: Computed with [Colour](https://github.com/KelSolaar/Colour/)
# 6. *Illuminants F Series*: https://law.resource.org/pub/us/cfr/ibr/003/cie.15.2004.tables.xls (Last accessed 24 February 2014)
# 7. *High Pressure Discharge Lamps*: https://law.resource.org/pub/us/cfr/ibr/003/cie.15.2004.tables.xls (Last accessed 12 June 2014)
# 8. Chromaticity Coordinates: http://en.wikipedia.org/wiki/Standard_illuminant#White_points_of_standard_illuminants (Last accessed 24 February 2014)
