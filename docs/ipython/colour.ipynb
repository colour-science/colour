# %% [markdown]
# # Colour

# %% [markdown]
# ## Introduction

# %% [markdown]
# [Colour](https://github.com/KelSolaar/Colour/) is a **Python** colour science package implementing a comprehensive number of colour theory transformations and algorithms.

# %%
from colour.implementation.matplotlib.plots import visible_spectrum_plot
visible_spectrum_plot()
# Out:
# True

# %% [markdown]
# ## Usage

# %% [markdown]
# This notebook is a companion guide and usage showcase. Most of the public API is available from the root *colour* namespace:

# %%
import colour
print(colour.__all__)
# Out:
# ['get_closest', 'get_steps', 'is_uniform', 'is_iterable', 'to_ndarray', 'is_number', 'cartesian_to_cylindrical', 'cylindrical_to_cartesian', 'cartesian_to_spherical', 'spherical_to_cartesian', 'Extrapolator1d', 'LinearInterpolator', 'SpragueInterpolator', 'is_identity', 'linear_regression', 'blackbody_spectral_power_distribution', 'blackbody_spectral_radiance', 'planck_law', 'CHROMATIC_ADAPTATION_METHODS', 'get_chromatic_adaptation_matrix', 'LMS_ConeFundamentals', 'RGB_ColourMatchingFunctions', 'XYZ_ColourMatchingFunctions', 'RGB_10_degree_cmfs_to_LMS_10_degree_cmfs', 'RGB_2_degree_cmfs_to_XYZ_2_degree_cmfs', 'RGB_10_degree_cmfs_to_XYZ_10_degree_cmfs', 'LMS_2_degree_cmfs_to_XYZ_2_degree_cmfs', 'LMS_10_degree_cmfs_to_XYZ_10_degree_cmfs', 'XYZ_to_Lab', 'Lab_to_XYZ', 'Lab_to_LCHab', 'LCHab_to_Lab', 'XYZ_to_Luv', 'Luv_to_XYZ', 'Luv_to_uv', 'Luv_uv_to_xy', 'Luv_to_LCHuv', 'LCHuv_to_Luv', 'XYZ_to_UCS', 'UCS_to_XYZ', 'UCS_to_uv', 'UCS_uv_to_xy', 'XYZ_to_UVW', 'XYZ_to_xyY', 'xyY_to_XYZ', 'xy_to_XYZ', 'XYZ_to_xy', 'is_within_macadam_limits', 'get_normalised_primary_matrix', 'get_RGB_luminance_equation', 'get_RGB_luminance', 'RGB_Colourspace', 'xyY_to_RGB', 'RGB_to_xyY', 'XYZ_to_RGB', 'RGB_to_XYZ', 'RGB_to_RGB', 'munsell_colour_to_xyY', 'get_munsell_value', 'munsell_value_priest1920', 'munsell_value_munsell1933', 'munsell_value_moon1943', 'munsell_value_saunderson1944', 'munsell_value_ladd1955', 'munsell_value_mccamy1987', 'MUNSELL_VALUE_FUNCTIONS', 'bandpass_correction', 'bandpass_correction_stearns', 'get_colour_rendering_index', 'delta_E_CIE_1976', 'delta_E_CIE_1994', 'delta_E_CIE_2000', 'delta_E_CMC', 'D_illuminant_relative_spd', 'mesopic_luminous_efficiency_function', 'mesopic_weighting_function', 'get_lightness', 'lightness_glasser1958', 'lightness_wyszecki1964', 'lightness_1976', 'LIGHTNESS_FUNCTIONS', 'get_luminance', 'luminance_newhall1943', 'luminance_1976', 'luminance_ASTM_D1535_08', 'LUMINANCE_FUNCTIONS', 'SpectralPowerDistribution', 'TriSpectralPowerDistribution', 'CCT_to_uv', 'CCT_to_uv_ohno2013', 'CCT_to_uv_robertson1968', 'uv_to_CCT', 'uv_to_CCT_ohno2013', 'uv_to_CCT_robertson1968', 'CCT_to_xy', 'CCT_to_xy_kang', 'CCT_to_xy_illuminant_D', 'xy_to_CCT', 'xy_to_CCT_mccamy', 'xy_to_CCT_hernandez', 'spectral_to_XYZ', 'wavelength_to_XYZ', 'CMFS', 'LMS_CMFS', 'RGB_CMFS', 'STANDARD_OBSERVERS_CMFS', 'COLORCHECKERS', 'COLORCHECKERS_SPDS', 'ACES_RGB_COLOURSPACE', 'ACES_RGB_LOG_COLOURSPACE', 'ACES_RGB_PROXY_10_COLOURSPACE', 'ACES_RGB_PROXY_12_COLOURSPACE', 'ADOBE_RGB_1998_COLOURSPACE', 'ADOBE_WIDE_GAMUT_RGB_COLOURSPACE', 'ALEXA_WIDE_GAMUT_RGB_COLOURSPACE', 'APPLE_RGB_COLOURSPACE', 'BEST_RGB_COLOURSPACE', 'BETA_RGB_COLOURSPACE', 'C_LOG_COLOURSPACE', 'CIE_RGB_COLOURSPACE', 'COLOR_MATCH_RGB_COLOURSPACE', 'DCI_P3_COLOURSPACE', 'DON_RGB_4_COLOURSPACE', 'ECI_RGB_V2_COLOURSPACE', 'EKTA_SPACE_PS_5_COLOURSPACE', 'MAX_RGB_COLOURSPACE', 'NTSC_RGB_COLOURSPACE', 'PAL_SECAM_RGB_COLOURSPACE', 'POINTER_GAMUT_DATA', 'PROPHOTO_RGB_COLOURSPACE', 'REC_709_COLOURSPACE', 'REC_2020_COLOURSPACE', 'RUSSELL_RGB_COLOURSPACE', 'S_LOG_COLOURSPACE', 'SMPTE_C_RGB_COLOURSPACE', 'sRGB_COLOURSPACE', 'XTREME_RGB_COLOURSPACE', 'RGB_COLOURSPACES', 'ILLUMINANTS', 'ILLUMINANTS_OPTIMAL_COLOUR_STIMULI', 'D_ILLUMINANTS_S_SPDS', 'ILLUMINANTS_RELATIVE_SPDS', 'LEFS', 'PHOTOPIC_LEFS', 'SCOTOPIC_LEFS', 'MUNSELL_COLOURS', 'TCS_SPDS', 'first_order_colour_fit']

# %% [markdown]
# The notebook has been divided in different chapters dedicated to showcase the API:
#
# * [Spectrum](spectrum.ipynb)
# * [Spectral Bandpass Dependence Correction](correction.ipynb)
# * [Colour Matching Functions](cmfs.ipynb)
# * [Luminous Efficiency Functions](lefs.ipynb)
# * [Blackbody](blackbody.ipynb)
# * [Illuminants](illuminants.ipynb)
# * [Colour Temperature & Correlated Colour Temperature](temperature.ipynb)
# * [Luminance, Munsell Value & Lightness](lightness.ipynb)
# * [Munsell Renotation System](munsell.ipynb)
